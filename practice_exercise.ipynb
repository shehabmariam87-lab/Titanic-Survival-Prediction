# %% [markdown]
# <a href="https://colab.research.google.com/github/shehabmariam87-lab/Titanic-Survival-Prediction/blob/main/practice_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Solve x + 2 = 3

x = 3 - 2

print("x =", x)
# Out:
# x = 1
